# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('CompleteDataset.csv')
# Out:
# C:\Users\i363894\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (23,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#        Unnamed: 0               Name  Age  \
# 0               0  Cristiano Ronaldo   32
# 1               1           L. Messi   30
# 2               2             Neymar   25
# 3               3          L. Suárez   30
# 4               4           M. Neuer   31
# 5               5     R. Lewandowski   28
# 6               6             De Gea   26
# 7               7          E. Hazard   26
# 8               8           T. Kroos   27
# 9               9         G. Higuaín   29
# 10             10       Sergio Ramos   31
# 11             11       K. De Bruyne   26
# 12             12        T. Courtois   25
# 13             13         A. Sánchez   28
# 14             14          L. Modrić   31
# 15             15            G. Bale   27
# 16             16          S. Agüero   29
# 17             17       G. Chiellini   32
# 18             18          G. Buffon   39
# 19             19          P. Dybala   23
# 20             20           J. Oblak   24
# ...

# %%
#resumo estatístico#
df.Club.describe
# Out:
# <bound method NDFrame.describe of 0                Real Madrid CF
# 1                  FC Barcelona
# 2           Paris Saint-Germain
# 3                  FC Barcelona
# 4              FC Bayern Munich
# 5              FC Bayern Munich
# 6             Manchester United
# 7                       Chelsea
# 8                Real Madrid CF
# 9                      Juventus
# 10               Real Madrid CF
# 11              Manchester City
# 12                      Chelsea
# 13                      Arsenal
# 14               Real Madrid CF
# 15               Real Madrid CF
# 16              Manchester City
# 17                     Juventus
# 18                     Juventus
# 19                     Juventus
# 20              Atlético Madrid
# 21              Atlético Madrid
# 22             FC Bayern Munich
# 23            Borussia Dortmund
# 24                        Milan
# 25             FC Bayern Munich
# 26              Atlético Madrid
# 27             FC Bayern Munich
# ...

# %%
#Requisitar o Valor máximo#
df.Potential.max()
# Out:
# 94

# %%
#Efetuar operações entre as colunas#
df['OverallPotential'] = df.Potential + df.Overall

# %%
df['OverallPotential'].head(5)
# Out:
# 0    188
# 1    186
# 2    186
# 3    184
# 4    184
# Name: OverallPotential, dtype: int64

# %%
#Plotar gráfico histograma#
df.Overall.plot.hist()

# %%
#Criar novo conjunto de dados pegando todos os dados da linha onde a coluna "Club" for FC Barcelona#
ssm = df.query('Club == "FC Barcelona"')

# %%
ssm.shape
# Out:
# (25, 78)

# %%
#Agrupando os dados por nacionalidade e vendo o numero de jogadores de cada país#
df.groupby('Nationality').size()
# Out:
# Nationality
# Afghanistan                3
# Albania                   35
# Algeria                   57
# Angola                    15
# Antigua & Barbuda          5
# Argentina                965
# Armenia                   14
# Australia                227
# Austria                  266
# Azerbaijan                 7
# Barbados                   1
# Belarus                    9
# Belgium                  272
# Belize                     1
# Benin                     14
# Bermuda                    4
# Bolivia                   30
# Bosnia Herzegovina        55
# Brazil                   812
# Brunei Darussalam          1
# Bulgaria                  33
# Burkina Faso              14
# Burundi                    1
# Cameroon                  86
# Canada                    55
# Cape Verde                22
# Central African Rep.       4
# Chad                       2
# Chile                    375
# China PR                  30
#                         ...
# ...

# %%
#Agrupando os dados por nacionalidade e vendo a média do portencial dos jogadores desses países#
df.groupby('Nationality').Potential.mean().round(1)
# Out:
# Nationality
# Afghanistan             66.3
# Albania                 70.8
# Algeria                 73.7
# Angola                  72.3
# Antigua & Barbuda       66.8
# Argentina               72.5
# Armenia                 70.7
# Australia               68.5
# Austria                 69.7
# Azerbaijan              69.0
# Barbados                65.0
# Belarus                 70.9
# Belgium                 74.1
# Belize                  69.0
# Benin                   72.0
# Bermuda                 66.0
# Bolivia                 68.4
# Bosnia Herzegovina      72.9
# Brazil                  72.9
# Brunei Darussalam       69.0
# Bulgaria                69.8
# Burkina Faso            72.9
# Burundi                 64.0
# Cameroon                72.8
# Canada                  68.7
# Cape Verde              72.8
# Central African Rep.    70.8
# Chad                    72.0
# Chile                   71.2
# China PR                69.7
#                         ...
# ...

# %%
df['JogadoresRuins'] = df.Potential < 50

# %%
sns.lmplot('Age', 'Overall', hue='JogadoresRuins', data=df)

# %%
plt.title('Potencial dos Jogadores do Barcelona')
ax = sns.countplot(x='Potential', hue='Name', data=ssm, )
plt.xlabel('Potencial')
plt.ylabel('')
ax.legend(title='Nome', bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
ssm.groupby('Nationality').size()
# Out:
# Nationality
# Argentina       2
# Belgium         1
# Brazil          2
# Croatia         1
# France          3
# Germany         1
# Netherlands     1
# Portugal        2
# Spain          10
# Turkey          1
# Uruguay         1
# dtype: int64
